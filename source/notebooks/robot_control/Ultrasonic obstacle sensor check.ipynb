# %% [markdown]
# # Ultrasonic obstacle sensor check

# %%
from proteas_lib import control

# %%
import time

# %%
control.start_lib()

# %%
ultra_obs = control.ultrasonic_sensor()

# %% [markdown]
# When the sensor return values ~2256 and higher should be considered as error values, use code to filter that values.

# %%
for i in range(1,100):
    print(ultra_obs.get_distance())
    time.sleep(0.2)
# Out:
# 2264.232897758484
# 2256.0142517089844
# 2256.688916683197
# 2258.332645893097
# 2256.3822507858276
# 2256.288206577301
# 2257.8256249427795
# 2250.588309764862
# 2256.3250064849854
# 2257.5475811958313
# 2256.758427619934
# 2256.3945174217224
# 2257.0446491241455
# 2256.2718510627747
# 2256.578516960144
# 2257.2041153907776
# 2256.210517883301
# 1451.3474702835083
# 88.58146667480469
# 11.67374849319458
# 7.339537143707275
# 6.623983383178711
# 5.511808395385742
# 2256.950604915619
# 191.21640920639038
# 2257.2654485702515
# 2258.042335510254
# 2257.6375365257263
# 2257.298159599304
# 2257.187759876251
# 2258.009624481201
# 2257.4249148368835
# 193.35898160934448
# 2260.9617948532104
# 2257.2736263275146
# 2257.0446491241455
# 2257.899224758148
# 2256.881093978882
# 170.3222393989563
# 170.8210825920105
# 171.9659686088562
# 169.7702407836914
# 169.59441900253296
# 170.19548416137695
# 171.1645483970642
# 170.40401697158813
# 170.39992809295654
# 170.64117193222046
# ...

# %%
control.clean()
